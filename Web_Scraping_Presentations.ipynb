# %%
# Importing required libraries

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Extract html for given url
url = 'https://ep70.eventpilotadmin.com/web/page.php?page=Session&project=AAIC19&id=5172&filterUrn=urn%3Aeventpilot%3Aall%3Aagenda%3Afilter%3Acategoryid%3DClinical+%28neuropsychiatry+and+behavioral+neurology%29'

page = requests.get(url)

# %%
# Parsing the data

soup = BeautifulSoup(page.content, 'html.parser')

list_items = soup.find_all('a', attrs = {'class' : 'catimg'})

base_url = 'https://ep70.eventpilotadmin.com/web/'
presentation_links = []

for ele in list_items: 
    presentation_links.append(base_url + ele['href'])

print('# of presentation links obtained : ' + str(len(presentation_links)))
# Out:
# # of presentation links obtained : 56

# %%
# Obtains abstract data for a presentation

def getAbstractData(abst_url):
    abstract_data = requests.get(abst_url)
    abst_soup = BeautifulSoup(abstract_data.content, 'html.parser')
    temp = abst_soup.find('div', 'abstract').text.strip()
    abst_index = temp.find('Background:')
    return temp[abst_index : ]

# %%
# Scraping the links
presentation_data = []

for link in presentation_links:

    page = requests.get(link)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Abstract title
    abstract_title = soup.find('li', 'session_detail_title_708').text

    # Time
    date_time_tag = soup.find_all('div', 'session_detail_day text_bannercolor')
    time = date_time_tag[0].text.strip()

    # Date
    date = date_time_tag[1].text.strip()
    date = date.replace(u'\xa0', u'')        # removing the &nbsp

    # Location
    location_abtract_no_tag = soup.find('span', 'ui-li-aside session_detail_location')
    location = location_abtract_no_tag.text.strip().split('\n')[0]

    # Abstract no
    abstract_no = location_abtract_no_tag.text.strip().split('\n')[1]

    # Authors and Author's Affiliations
    authors = ""
    affiliations = ""
    authors_data = soup.find('div', 'detail_description').text.strip().split('\n')[0]
    index = authors_data.find('Author')
    aff_index = authors_data.find('(1)')

    if aff_index == -1:
        affiliations = ''
        authors = authors_data[index : ]
    else:
        authors = authors_data[index : aff_index]
        affiliations = authors_data[aff_index : ]


    # Category
    filters = soup.find_all('div', 'filter_value')
    category = filters[0].text 

    # Sub-category
    sub_category = filters[1].text
    
    # Abstract text
    abstract_tag = soup.find_all('div', 'mediabgicon')[0].parent
    abst_url = base_url + abstract_tag['href']
    abstract_text = getAbstractData(abst_url)
    
    # Session title
    session_title = soup.find('div', 'session_title list_cell_title').text
    session = [abstract_no, abstract_title, date, time, location, abst_url, authors, affiliations, 
           abstract_text, category, sub_category, session_title]
    
    print('Extracted ' + abstract_no + ' : ' + abstract_title)
    presentation_data.append(session)   
    
print('\nExtracted all presentation data.')
# Out:
# Extracted P2-265 : The Clinical Characteristics of Cognitive Impairment in Patients with Small Vessel Disease
# Extracted P2-266 : A History-Based Computerized Questionnaire for the Diagnosis of Severity and Subtypes of Dementia: Design and Verify
# Extracted P2-267 : Moral Emotions in Frontotemporal Dementia
# Extracted P2-268 : Validity of the Everyday Cognition (ECog) As a Screening Measure of Subjective Cognitive Decline (SCD)
# Extracted P2-269 : Geriatric Depression Scale Item-Level Analysis in Relation to In Vivo Cortical Amyloid and Cerebral Regional Tau in Clinically Normal Older Adults: Findings from the Harvard Aging Brain Study
# Extracted P2-270 : Protective Role of Orexinergic System Overexpression on Cognitive Function in Alzheimer Disease Patients
# Extracted P2-271 : The Effect of African American Race on Neurobehavioral Outcomes, Structural MRI Indices, and Cerebrospinal Fluid Concentrations of Tau and Aβ in Former National Football League Players
# Extracted P2-272 : Prevalence of Cognitive Impairment Among Peritoneal Dialysis Patients: A Systematic Review and Meta-Analysis
# Extracted P2-273 : Clinical-Neuropathological Correlations of Alzheimer’s Disease and Related Dementias in Latino Volunteers
# Extracted P2-274 : Muscle Profile and Progression of Alzheimer’S Dementia: Predictors of Poor Clinical Outcome and Role of Muscle Profile, a 3-Years Longitudinal Study
# Extracted P2-275 : Clinical Characteristics of Pathologicaly Confirmed Early Onset Dementia with Lewy Bodies
# Extracted P2-276 : Alzheimer's Disease: Vitamin D Deficiency Is Associated with Lower Mini-Mental State Exam (MMSE) Scores When Compared to Vitamin D Normal Range
# Extracted P2-277 : Rapid Progressive Dementia in Hdls with a Novel CSF1R Mutation
# Extracted P2-279 : Diagnostic Diversity and Three-Year Mortality Risk in a Memory Clinic
# Extracted P2-280 : Early-Onset Dementia in Chinese
# Extracted P2-281 : Dementia Outcomes after Addition of Proxy-Based Assessments for Deceased or Proxy-Dependent Participants
# Extracted P2-282 : Prognostic Regression Models of Life Expectancy after Diagnosis of Alzheimer’s Disease—a 20-Year Follow-up
# Extracted P2-283 : Current Status, Diagnosis and Treatment of Patients in a Memory Clinic in Chongqing, Southwestern China: An Eight-Year Practice
# Extracted P2-284 : Association of Alzheimer's Disease with the Risk of Developing Epilepsy: A 10-Year Nationwide Cohort Study
# Extracted P2-285 : Correlating Family History to Age of Diagnosis of Dementia in a Memory Clinic
# Extracted P2-286 : Unawareness of Cognitive Impairment in Alzheimer’s Disease: A Review of the Current State of Art
# Extracted P2-287 : Insomnia Increases the Risk of Alzheimer’s Disease and Vascular Dementia: A Nationwide Population-Based Study in South Korea
# Extracted P2-288 : Two Novel Mutations in CSF1R Causing Hereditary Diffuse Leukoencephalopathy with Axonal Spheroids (HDLS)
# Extracted P2-289 : Predictors of Decline in Early Onset Alzheimer’s Dementia: A Retrospective Cohort Study
# Extracted P2-290 : Comparison of Self and Informant Evaluated Korean Dementia Screening Questionnaire Cognition (KDSQ-C) for the Diagnosis of Mild Cognitive Impairment and Dementia
# Extracted P2-291 : Head Turn Sign. Highly Simply and Specific for Dementia Diagnosis
# Extracted P2-292 : The Pattern of Inheritance in Early Onset Alzheimer’s Disease and Frontotemporal Dementia
# Extracted P2-293 : An Investigation of Various Cardiovascular Risk Factors and Their Effects on Intra-Individual Cognitive  Variability.
# Extracted P2-294 : Retrospective Review of Clinical Features of ABCA7 Loss-of-Function Mutation Carriers in Late-Onset Alzheimer's Disease
# Extracted P2-295 : Fluctuating Cognition in Non Lewy Body Dementia and Its Clinical Implication
# Extracted P2-296 : Decision Making Time in Patients with Mild Cognitive Impairment and Dementia Assessed with Simple Reaction Time and Go/No-Go Task
# Extracted P2-297 : Epilepsy in Alzheimer Disease Is Frequent and Characterized By High Recurrence
# Extracted P2-298 : Predictors of Poor Clinical Outcome and Role of Muscle Profile in Alzheimer's Disease: A 3-Years Longitudinal Study
# Extracted P2-299 : Effect of Apolipoprotein E ε4 Allele on Progression Rate of Cognitive Decline in Prodromal and Mild Alzheimer's Disease.
# Extracted P2-300 : The Blood Pressure Level Is Associated with Plasma Amyloid-β Levels：a Cross-Sectional Study in the Suburbs of Xi'an, China
# Extracted P2-301 : Differences in Cognitive Profile between Biomarker Confirmed Alzheimer’s Disease and Vascular Dementia
# Extracted P2-302 : REM Sleep Behavior Disorder in Alzheimer’s Disease: Prevalence and Association Factors
# Extracted P2-303 : Frontotemporal Dementia As a Mimic of Psychosis: Case Report
# Extracted P2-304 : An Economic Evaluation of a Novel Computerized Cognitive Test in Dementia
# Extracted P2-305 : Higher Cortical Functions Evaluation Study in Patients with Alzheimer's Disease in Uzbekistan.
# Extracted P2-306 : Association of Performance in Tasks of Executive Function and Theory of Mind, with Tasks of Practical Judgment in Healthy Older Adults, with Mild Cognitive Impairment, Alzheimer's Disease and Behavioral Variant of Frontotemporal Dementia
# Extracted P2-307 : Decode Dementia: Initial Development and External Validation of Clinical Prediction Models for Dementia Identification
# Extracted P2-308 : Clinical Characteristics of Early-Onset Alzheimer’s Disease: A Clinical Research Center for Dementia of South Korea (CREDOS) Study
# Extracted P2-310 : Specificities of Early Onset Alzheimer’s Disease
# Extracted P2-311 : Dementia and the Risk of New Onset Seizures: A Cohort Study of a National US Managed Care Database
# Extracted P2-312 : Validation of the Korean Version of the Anosognosia Questionnaire for Dementia
# Extracted P2-313 : Dysexecutive Syndrome in Multi- Infarct Versus Subcortical Ischaemic Small Vessel Disease Dementia
# Extracted P2-314 : The Multidomain Impairment Rating (MIR) Scale: Initial Reliability DATA on a Multidimensional Scale Designed for Ftld Spectrum Disorders
# Extracted P2-315 : Sleep Disorder Increases the Risk of Incident Dementia and Alzheimer’s Disease in Persons with Central Nervous System Trauma: A Retrospective Cohort Study.
# Extracted P2-316 : Work in Progress: An Industry-Clinical-Academic Partnership for Digital and Persistent Assessment of Motor and Cognitive-Linguistic Outcomes
# Extracted P2-318 : The Role of Sex in Motor and Cognitive Trajectories before Dementia
# Extracted P2-319 : New Unprovoked Idiopathic Seizures and Later Development of Dementia, a Case Series.
# Extracted P2-320 : Argentinian Initiative for the Study of Down Syndrome and Alzheimer´s Disease (IASDA)
# Extracted P2-321 : Clinical Characteristics of Non-Amnestic Mild Cognitive Impairment: A Single-Center Experience
# Extracted P2-323 : Study on the Relationship between Sleep Disorder and Cognitive Impairment in Patients with Alzheimer's Disease
# Extracted P2-324 : Openness Personality Trait Predicts Delayed Verbal Recall at > 1 Year Follow-up in Cognitively-Normal Older Adults without Current or Lifetime History of Psychiatric Illness

# %%
# Saving data to pandas dataframe
column_names = ['Abstract #', 'Abstract Title', 'Date', 'Time', 'Location', 'URL', 'Authors',
                'Author\'s Affiliations', 'Abstract Text', 'Category', 'Sub-category', 'Session Title']

df = pd.DataFrame(presentation_data, columns=column_names)
df.set_index("Abstract #", inplace = True)
df.head()
# Out:
#                                                Abstract Title  \
# Abstract #
# P2-265      The Clinical Characteristics of Cognitive Impa...
# P2-266      A History-Based Computerized Questionnaire for...
# P2-267              Moral Emotions in Frontotemporal Dementia
# P2-268      Validity of the Everyday Cognition (ECog) As a...
# P2-269      Geriatric Depression Scale Item-Level Analysis...
#
#                              Date             Time  \
# Abstract #
# P2-265      Mon, Jul 15 (Pacific)  9:30am - 4:15pm
# P2-266      Mon, Jul 15 (Pacific)  9:30am - 4:15pm
# P2-267      Mon, Jul 15 (Pacific)  9:30am - 4:15pm
# P2-268      Mon, Jul 15 (Pacific)  9:30am - 4:15pm
# P2-269      Mon, Jul 15 (Pacific)  9:30am - 4:15pm
#
#                                                  Location  \
# Abstract #
# P2-265      South Hall GH - Los Angeles Convention Center
# P2-266      South Hall GH - Los Angeles Convention Center
# P2-267      South Hall GH - Los Angeles Convention Center
# P2-268      South Hall GH - Los Angeles Convention Center
# P2-269      South Hall GH - Los Angeles Convention Center
#
#                                                           URL  \
# Abstract #
# P2-265      https://ep70.eventpilotadmin.com/web/page.php?...
# P2-266      https://ep70.eventpilotadmin.com/web/page.php?...
# P2-267      https://ep70.eventpilotadmin.com/web/page.php?...
# P2-268      https://ep70.eventpilotadmin.com/web/page.php?...
# P2-269      https://ep70.eventpilotadmin.com/web/page.php?...
#
#                                                       Authors  \
# Abstract #
# P2-265      Author Block: Junliang Yuan Sr., MD, McLean Ho...
# P2-266      Author Block: Pai-Yi Chiu, MD, PhD, Show Chwan...
# P2-267      Author Block: Chloé Daigmorte1; Marc Teichmann...
# P2-268      Author Block: Minji Song, MA1,2; Lee Sun Hwa, ...
# P2-269      Author Block: Jennifer R Gatchel, MD, PhD1,2,3...
#
#                                         Author's Affiliations  \
# Abstract #
# P2-265
# P2-266
# P2-267      (1)APHP- Groupe Hospitalier Pitie Salpetriere,...
# P2-268      (1)Hallym University Chuncheon Sacred Heart Ho...
# P2-269      (1)Massachusetts General Hospital, Boston, MA,...
#
#                                                 Abstract Text  \
# Abstract #
# P2-265      Background: To explore the clinical characteri...
# P2-266      Background: It is difficult for non-specialist...
# P2-267      Background: Frontotemporal dementia (bv-FTD) i...
# P2-268      Background: Everyday Cognition (ECog, Farias e...
# P2-269      Background: While evidence suggests that depre...
#
#                            Category  \
# Abstract #
# P2-265      Diagnosis and Prognosis
# P2-266      Diagnosis and Prognosis
# P2-267      Diagnosis and Prognosis
# P2-268      Diagnosis and Prognosis
# P2-269      Diagnosis and Prognosis
#
#                                                  Sub-category  \
# Abstract #
# P2-265      Clinical (neuropsychiatry and behavioral neuro...
# P2-266      Clinical (neuropsychiatry and behavioral neuro...
# P2-267      Clinical (neuropsychiatry and behavioral neuro...
# P2-268      Clinical (neuropsychiatry and behavioral neuro...
# P2-269      Clinical (neuropsychiatry and behavioral neuro...
#
#                                                 Session Title
# Abstract #
# P2-265      [Posters Mon] Diagnosis and Prognosis： Clinica...
# P2-266      [Posters Mon] Diagnosis and Prognosis： Clinica...
# P2-267      [Posters Mon] Diagnosis and Prognosis： Clinica...
# P2-268      [Posters Mon] Diagnosis and Prognosis： Clinica...
# P2-269      [Posters Mon] Diagnosis and Prognosis： Clinica...

# %%
# Saving data to excel file
fname = 'Conf Web Planner (Output File).xlsx'
df.to_excel(fname)
print('Saved to ' + fname)
# Out:
# Saved to Conf Web Planner (Output File).xlsx
